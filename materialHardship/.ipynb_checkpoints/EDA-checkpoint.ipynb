# %% [markdown]
# Here is an attempt to use a neural network to make FFC material hardship predictions.

# %% [markdown]
# 1. [Imports](#ims)
# 2. [Data preprocessing](#pp)

# %% [markdown]
# # 1. Imports<a name="ims"></a>

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df_train, df_prediction, non_na_y_train_materialHardship = pd.read_pickle('df_train'), pd.read_pickle('df_prediction'), pd.read_pickle('non_na_y_train_materialHardship')

# %% [markdown]
# Check out what kinds of data we have:

# %%
# distribution of different data types
df_train.dtypes.value_counts()
# Out:
# int64      9489
# float64    3307
# object      147
# dtype: int64

# %% [markdown]
# # 2. EDA<a name="pp"></a>

# %% [markdown]
# ## 2a. Labels <a name="pp"></a>

# %%
train = pd.read_csv('train.csv')

# %%
sns.pairplot(train.dropna())
plt.show()

# %% [markdown]
# The materialHardship data is **imbalanced**.

# %%
non_na_y_train_materialHardship['materialHardship'].value_counts().reset_index()
# Out:
#       index  materialHardship
# 0  0.000000               807
# 1  0.090909               248
# 2  0.181818               136
# 3  0.272727               104
# 4  0.363636                61
# 5  0.454545                58
# 6  0.545455                26
# 7  0.636364                11
# 8  0.727273                 6
# 9  0.818182                 2

# %%
non_na_y_train_materialHardship['MH Score'] = non_na_y_train_materialHardship['materialHardship']*11

# %%
sns.set(font_scale=3)  # crazy big
xx=sns.countplot(x='MH Score', data=non_na_y_train_materialHardship)
sns.plt.suptitle('Material Hardship scores (0 to 11 scale)')
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
fig.savefig('test2png.png', dpi=100)

# %%
sns.distplot(non_na_y_train_materialHardship['materialHardship'])
plt.show()

# %% [markdown]
# Most of the {{len(non_na_y_train_materialHardship)}} individuals do not experience material hardship. See this [link](http://www.fragilefamilieschallenge.org/material-hardship/) for documentation on this variable.

# %%
train = pd.read_csv('train.csv')

# %% [markdown]
# ## 2b. Features <a name="pp"></a>

# %% [markdown]
# How do you do EDA on 13k features?
