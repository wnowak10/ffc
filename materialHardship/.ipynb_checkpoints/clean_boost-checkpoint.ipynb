# %% [markdown]
# # Intro
#
# As the title indicates, this ipynb aims to import dataframes (features plus labels) and then develop functions / clases to process data, fit models, and make predictions!

# %% [markdown]
# # Import data (just for materialHardship)

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

import sys
import math

# %%
mean_impute_df_train_with_labels = pd.read_pickle('mean_impute_df_train_with_labels')
median_impute_df_train_with_labels  = pd.read_pickle('median_impute_df_train_with_labels')

# %%
final_over_balanced =  pd.read_pickle('final_over_balanced_decimals')

# %%
df_prediction =  pd.read_pickle('df_prediction')

# %% [markdown]
# Read files from pickles...we are reading full dataframes, with columns of features attached to label columns. Function below is used to split features from class labels and make models and predictions.

# %% [markdown]
# # Train

# %% [markdown]
# ## Prepare data

# %% [markdown]
# # Add families feature.

# %%
from sklearn.cluster import Birch, MiniBatchKMeans
mbk = MiniBatchKMeans(init='k-means++', n_clusters=1000, batch_size=100,
                      n_init=10, max_no_improvement=10, verbose=0,
                      random_state=0)
mbk.fit(median_impute_df_train_with_labels) # took ~10 mins to run
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/sklearn/cluster/k_means_.py:1381: RuntimeWarning: init_size=300 should be larger than k=1000. Setting it to 3*k
#   init_size=init_size)
# MiniBatchKMeans(batch_size=100, compute_labels=True, init='k-means++',
#         init_size=None, max_iter=100, max_no_improvement=10,
#         n_clusters=1000, n_init=10, random_state=0,
#         reassignment_ratio=0.01, tol=0.0, verbose=0)

# %%
median_impute_df_train_with_labels['family id?'] = mbk.labels_

# %% [markdown]
# Split features and labels.

# %%
# split data into features and labels
def split_data(df, label='materialHardship'):
    copy = df.copy() # copy df so i dont alter original df by popping
    y = copy.pop(label) # pop label
    return copy, y

# %% [markdown]
# Return features and labels...feed split_data function a full data frame. This can be any from the above imports.

# %%
copy, mh = split_data(median_impute_df_train_with_labels)

# %% [markdown]
# Test_train split. I call the test data the "validation" data because I think it is a better, less ambiguous term.

# %%
x_train_med, x_valid_med, y_train_med, y_valid_med = train_test_split(copy, mh, test_size=0.2) #train test split

# %%
# x_train_med

# %% [markdown]
# Now, let's take the training set and increase its size / balance classes using SMOTE.

# %% [markdown]
# # SMOTE on training set

# %% [markdown]
# First, take the train features and labels we just made and put back together. Do this by leaving out validation challenge ids.

# %%
median_all = median_impute_df_train_with_labels.loc[median_impute_df_train_with_labels['challengeID'].isin(x_train_med['challengeID'])]
median_all
# Out:
#       challengeID  m1intmon  m1lenhr  m1lenmin  cm1fint  cm1citsm  \
# 0             6.0      -3.0      0.0      25.0      1.0       1.0
# 1             7.0      -3.0      0.0      35.0      1.0       1.0
# 2             9.0      -3.0      0.0      30.0      1.0       1.0
# 3            10.0      -3.0      0.0      33.0      1.0       1.0
# 4            13.0      -3.0      1.0      -3.0      1.0       1.0
# 5            14.0      -3.0      0.0      25.0      1.0       1.0
# 6            16.0      -3.0      0.0      30.0      1.0       1.0
# 8            20.0      -3.0     -3.0      25.0      0.0       1.0
# 9            23.0      -3.0      1.0       0.0      1.0       1.0
# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42,k_neighbors=1)

# %%
median_all_low_mh = median_all[median_all['materialHardship']/11<(7/11)] # just look for obs where mh < 7

# %%
y = median_all_low_mh['materialHardship']
y_arr = np.asarray(y)

x = median_all_low_mh.drop('materialHardship', axis=1)
x_arr =np.asarray(x)

# %%
yy = y/11

# %%
X_resamp, y_resamp = sm.fit_sample(x, yy)
X_resamp, y_resamp = sm.fit_sample(X_resamp, y_resamp) # call multiple times to iterature though all classes
X_resamp, y_resamp = sm.fit_sample(X_resamp, y_resamp)
X_resamp, y_resamp = sm.fit_sample(X_resamp, y_resamp)
X_resamp, y_resamp = sm.fit_sample(X_resamp, y_resamp)
X_resamp, y_resamp = sm.fit_sample(X_resamp, y_resamp)
X_resamp, y_resamp = sm.fit_sample(X_resamp, y_resamp)
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# /anaconda/envs/py35/lib/python3.5/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# /anaconda/envs/py35/lib/python3.5/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# /anaconda/envs/py35/lib/python3.5/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# /anaconda/envs/py35/lib/python3.5/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# /anaconda/envs/py35/lib/python3.5/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')
# /anaconda/envs/py35/lib/python3.5/site-packages/imblearn/base.py:306: UserWarning: The target type should be binary.
#   warnings.warn('The target type should be binary.')

# %%
from collections import Counter
print('Resampled dataset shape {}'.format(Counter(y_resamp)))
# Out:
# Resampled dataset shape Counter({0.09090909090909091: 651, 0.0: 651, 0.18181818181818182: 651, 0.2727272727272727: 651, 0.5454545454545454: 651, 0.45454545454545453: 651, 0.36363636363636365: 651})

# %%
x_resamped = pd.DataFrame(X_resamp)

x_resamped.columns = copy.columns.values
x_resamped.reset_index(inplace=True)
x_resamped.head()
# Out:
#    index  challengeID  m1intmon  m1lenhr  m1lenmin  cm1fint  cm1citsm  \
# 0      0          6.0      -3.0      0.0      25.0      1.0       1.0
# 1      1          7.0      -3.0      0.0      35.0      1.0       1.0
# 2      2          9.0      -3.0      0.0      30.0      1.0       1.0
# 3      3         10.0      -3.0      0.0      33.0      1.0       1.0
# 4      4         13.0      -3.0      1.0      -3.0      1.0       1.0
#
#      m1citywt  innatsm  incitysm     ...          m4e23       f4d6      f4d7  \
# 0   10.593024      1.0       1.0     ...      10.558813  -3.000000 -3.000000
# 1  531.335144      1.0       1.0     ...      -3.000000   9.660643  9.861125
# 2   90.466721      0.0       1.0     ...      -3.000000  11.689877  9.373199
# 3    6.155746      1.0       1.0     ...      -3.000000  -3.000000 -3.000000
# 4    5.496325      0.0       1.0     ...      -3.000000  -3.000000 -3.000000
#
#        f4d9       m5c6      m5d20  m5k10       f5c6       k5f1  family id?
# 0  7.022328  -3.000000  10.564085   -3.0  -3.000000  10.255825       686.0
# 1 -3.000000  10.991854  -3.000000   -3.0  10.972726  10.859800       648.0
# 2 -3.000000   8.194868  -3.000000   -3.0   9.842380   9.566678       849.0
# 3 -3.000000  -3.000000  10.564085   -3.0  -3.000000  10.105870       469.0
# 4  8.944119  -3.000000   9.781718   -3.0  -3.000000   9.566678       386.0
#
# [5 rows x 11986 columns]

# %%
y_resamped = pd.DataFrame(y_resamp)
y_resamped.columns = ['materialHardship']
y_resamped.reset_index(inplace=True)

# %%
y_resamped.head()
# Out:
#    index materialHardship
# 0      0        0.0909091
# 1      1                0
# 2      2         0.181818
# 3      3        0.0909091
# 4      4         0.181818

# %%
resamped_x_y = pd.merge(x_resamped, y_resamped, on='index')
resamped_x_y.head()
# Out:
#    index  challengeID  m1intmon  m1lenhr  m1lenmin  cm1fint  cm1citsm  \
# 0      0          6.0      -3.0      0.0      25.0      1.0       1.0
# 1      1          7.0      -3.0      0.0      35.0      1.0       1.0
# 2      2          9.0      -3.0      0.0      30.0      1.0       1.0
# 3      3         10.0      -3.0      0.0      33.0      1.0       1.0
# 4      4         13.0      -3.0      1.0      -3.0      1.0       1.0
#
#      m1citywt  innatsm  incitysm        ...              f4d6      f4d7  \
# 0   10.593024      1.0       1.0        ...         -3.000000 -3.000000
# 1  531.335144      1.0       1.0        ...          9.660643  9.861125
# 2   90.466721      0.0       1.0        ...         11.689877  9.373199
# 3    6.155746      1.0       1.0        ...         -3.000000 -3.000000
# 4    5.496325      0.0       1.0        ...         -3.000000 -3.000000
#
#        f4d9       m5c6      m5d20  m5k10       f5c6       k5f1  family id?  \
# 0  7.022328  -3.000000  10.564085   -3.0  -3.000000  10.255825       686.0
# 1 -3.000000  10.991854  -3.000000   -3.0  10.972726  10.859800       648.0
# 2 -3.000000   8.194868  -3.000000   -3.0   9.842380   9.566678       849.0
# 3 -3.000000  -3.000000  10.564085   -3.0  -3.000000  10.105870       469.0
# 4  8.944119  -3.000000   9.781718   -3.0  -3.000000   9.566678       386.0
#
#    materialHardship
# 0         0.0909091
# 1                 0
# 2          0.181818
# 3         0.0909091
# 4          0.181818
#
# [5 rows x 11987 columns]

# %%
high_mh = median_all[median_all['materialHardship']/11>=(7/11)] # just look for obs where mh < 7
high_mh['materialHardship'] = high_mh['materialHardship']/11
high_mh.head()
# Out:
# /anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#      challengeID  m1intmon  m1lenhr  m1lenmin  cm1fint  cm1citsm   m1citywt  \
# 103        297.0      -3.0     -3.0      35.0      0.0       1.0  16.421036
# 117        324.0      -3.0      0.0      45.0      1.0       1.0  35.041477
# 272        766.0      -3.0     -3.0      35.0      1.0       1.0  64.060135
# 352        981.0      -3.0      0.0      30.0      1.0       1.0  19.928909
# 374       1029.0      -3.0     -3.0      55.0      0.0       1.0  27.672316
#
#      innatsm  incitysm  m1a3     ...      f4d6  f4d7     f4d9      m5c6  \
# 103      0.0       1.0   2.0     ...      -3.0  -3.0 -3.00000 -3.000000
# 117      1.0       1.0   1.0     ...      -3.0  -3.0 -3.00000 -3.000000
# 272      0.0       1.0   1.0     ...      -3.0  -3.0 -3.00000 -3.000000
# 352      0.0       1.0   1.0     ...      -3.0  -3.0  8.61341 -3.000000
# 374      1.0       1.0   2.0     ...      -3.0  -3.0 -3.00000  8.376201
#
#          m5d20  m5k10      f5c6       k5f1  materialHardship  family id?
# 103  10.564085   -3.0 -3.000000   9.566678          0.727273          31
# 117  -3.000000   -3.0 -3.000000  10.724639          0.818182         579
# 272  -3.000000   -3.0 -3.000000   9.566678          0.727273         966
# 352   9.162070   -3.0 -3.000000   9.566678          0.636364         952
# 374  -3.000000   -3.0  9.802608   9.566678          0.636364         366
#
# [5 rows x 11986 columns]

# %%
final_over_balanced = resamped_x_y.append(high_mh)

# %%
import seaborn as sns 
sns.distplot(final_over_balanced['materialHardship'])
plt.show()

# %%
final_over_balanced = final_over_balanced.drop('index', 1)
final_over_balanced.head()
# Out:
#      c2citywt  c2citywt_rep1  c2citywt_rep10  c2citywt_rep2  c2citywt_rep3  \
# 0   11.134632      13.075468       13.862883      13.057703      11.229993
# 1   41.145229      38.750587       35.888996      38.882961      38.353191
# 2  104.055870     107.864006        0.000000     104.398315     109.786621
# 3   41.145229      38.750587       35.888996      38.882961      38.353191
# 4    8.702942      11.572806        8.381824       9.364669       9.504119
#
#    c2citywt_rep4  c2citywt_rep5  c2citywt_rep6  c2citywt_rep7  c2citywt_rep8  \
# 0      12.411758      12.993218      13.358963       0.000000      11.579317
# 1      37.669495      39.116447      38.526501      39.675743      39.874935
# 2     121.313026     123.207191     124.847580     114.975273     110.409531
# 3      37.669495      39.116447      38.526501      39.675743      39.874935
# 4       0.000000      11.012741      10.537480       9.394835      12.157079
#
#     ...    t5g4i  t5g4j  t5g4k  t5g5  t5g6  t5g7  t5g8  t5g9_age  t5status  \
# 0   ...     -3.0   -3.0   -3.0  -3.0  -3.0  -3.0  -3.0      -3.0      -9.0
# 1   ...     -3.0   -3.0   -3.0  -3.0  -3.0  -3.0  -3.0      -3.0      -9.0
# 2   ...     -3.0   -3.0   -3.0  -3.0  -3.0  -3.0  -3.0      -3.0      65.0
# 3   ...     -3.0   -3.0   -3.0  -3.0  -3.0  -3.0  -3.0      -3.0      -9.0
# 4   ...     -3.0   -3.0   -3.0  -3.0  -3.0  -3.0  -3.0      -3.0      -9.0
#
#    t5tint
# 0     0.0
# 1     0.0
# 2     1.0
# 3     0.0
# 4     0.0
#
# [5 rows x 11986 columns]

# %%
to_train = final_over_balanced.pop('challengeID')

# %%
y = final_over_balanced.pop('materialHardship')

# %%
final_over_balanced.head()
# Out:
#      c2citywt  c2citywt_rep1  c2citywt_rep10  c2citywt_rep2  c2citywt_rep3  \
# 0   11.134632      13.075468       13.862883      13.057703      11.229993
# 1   41.145229      38.750587       35.888996      38.882961      38.353191
# 2  104.055870     107.864006        0.000000     104.398315     109.786621
# 3   41.145229      38.750587       35.888996      38.882961      38.353191
# 4    8.702942      11.572806        8.381824       9.364669       9.504119
#
#    c2citywt_rep4  c2citywt_rep5  c2citywt_rep6  c2citywt_rep7  c2citywt_rep8  \
# 0      12.411758      12.993218      13.358963       0.000000      11.579317
# 1      37.669495      39.116447      38.526501      39.675743      39.874935
# 2     121.313026     123.207191     124.847580     114.975273     110.409531
# 3      37.669495      39.116447      38.526501      39.675743      39.874935
# 4       0.000000      11.012741      10.537480       9.394835      12.157079
#
#     ...    t5g4i  t5g4j  t5g4k  t5g5  t5g6  t5g7  t5g8  t5g9_age  t5status  \
# 0   ...     -3.0   -3.0   -3.0  -3.0  -3.0  -3.0  -3.0      -3.0      -9.0
# 1   ...     -3.0   -3.0   -3.0  -3.0  -3.0  -3.0  -3.0      -3.0      -9.0
# 2   ...     -3.0   -3.0   -3.0  -3.0  -3.0  -3.0  -3.0      -3.0      65.0
# 3   ...     -3.0   -3.0   -3.0  -3.0  -3.0  -3.0  -3.0      -3.0      -9.0
# 4   ...     -3.0   -3.0   -3.0  -3.0  -3.0  -3.0  -3.0      -3.0      -9.0
#
#    t5tint
# 0     0.0
# 1     0.0
# 2     1.0
# 3     0.0
# 4     0.0
#
# [5 rows x 11984 columns]

# %%
num_rd = [1,5]
i=1
paramms = {
        "eval_metric" : 'rmse',
        'objective' : 'reg:logistic',
        'eta' : .02,
        'max_depth': 20
       }

# %%
x_valid_med.shape
# Out:
# (292, 11984)

# %%
final_over_balanced.shape
# Out:
# (4575, 11984)

# %%
y.shape
# Out:
# (4575,)

# %%
y_valid_med.shape
# Out:
# (292,)

# %%
x_valid_med = x_valid_med[final_over_balanced.columns.values]

# %%
d_train = xgb.DMatrix(final_over_balanced,y/11) # make training matrix
d_valid = xgb.DMatrix(x_valid_med,y_valid_med/11) # make valid matrix
watchlist = [(d_train, 'train'), (d_valid, 'valid')]

bst = xgb.train(params=paramms,  # train on train matrix with params
            dtrain=d_train,
            evals = watchlist,
         num_boost_round=300)
# Out:
# [0]	train-rmse:0.465867	valid-rmse:0.416399
# [1]	train-rmse:0.456574	valid-rmse:0.407768
# [2]	train-rmse:0.44747	valid-rmse:0.399341
# [3]	train-rmse:0.438551	valid-rmse:0.391114
# [4]	train-rmse:0.429812	valid-rmse:0.383085
# [5]	train-rmse:0.421251	valid-rmse:0.375249
# [6]	train-rmse:0.412863	valid-rmse:0.367603
# [7]	train-rmse:0.404645	valid-rmse:0.360143
# [8]	train-rmse:0.396592	valid-rmse:0.352867
# [9]	train-rmse:0.388703	valid-rmse:0.345772
# [10]	train-rmse:0.380972	valid-rmse:0.338854
# [11]	train-rmse:0.373398	valid-rmse:0.33211
# [12]	train-rmse:0.365976	valid-rmse:0.325538
# [13]	train-rmse:0.358703	valid-rmse:0.319134
# [14]	train-rmse:0.351577	valid-rmse:0.312896
# [15]	train-rmse:0.344594	valid-rmse:0.306821
# [16]	train-rmse:0.337752	valid-rmse:0.300907
# [17]	train-rmse:0.331048	valid-rmse:0.29515
# [18]	train-rmse:0.324478	valid-rmse:0.289549
# [72]	train-rmse:0.110906	valid-rmse:0.155494
# [73]	train-rmse:0.108749	valid-rmse:0.155057
# [74]	train-rmse:0.106633	valid-rmse:0.1547
# [75]	train-rmse:0.104561	valid-rmse:0.154339
# [76]	train-rmse:0.10253	valid-rmse:0.154024
# [77]	train-rmse:0.10054	valid-rmse:0.153734
# [78]	train-rmse:0.098589	valid-rmse:0.153483
# [79]	train-rmse:0.096679	valid-rmse:0.153257
# [80]	train-rmse:0.094806	valid-rmse:0.15307
# [81]	train-rmse:0.092972	valid-rmse:0.152902
# [82]	train-rmse:0.091174	valid-rmse:0.152751
# [83]	train-rmse:0.089412	valid-rmse:0.152642
# [84]	train-rmse:0.087684	valid-rmse:0.152573
# [85]	train-rmse:0.085993	valid-rmse:0.152504
# [86]	train-rmse:0.084334	valid-rmse:0.152464
# [87]	train-rmse:0.08271	valid-rmse:0.152427
# [88]	train-rmse:0.081118	valid-rmse:0.152433
# [89]	train-rmse:0.079559	valid-rmse:0.152446
# [90]	train-rmse:0.07803	valid-rmse:0.152466
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-e70844a1e296> in <module>()
#       6             dtrain=d_train,
#       7             evals = watchlist,
# ----> 8          num_boost_round=300)
#
# /Users/wnowak/Downloads/xgboost-0.6a2/xgboost/xgboost/python-package/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     202                            evals=evals,
#     203                            obj=obj, feval=feval,
# --> 204                            xgb_model=xgb_model, callbacks=callbacks)
#     205
#     206
#
# /Users/wnowak/Downloads/xgboost-0.6a2/xgboost/xgboost/python-package/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /Users/wnowak/Downloads/xgboost-0.6a2/xgboost/xgboost/python-package/xgboost/core.py in update(self, dtrain, iteration, fobj)
#     817
#     818         if fobj is None:
# --> 819             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, iteration, dtrain.handle))
#     820         else:
#     821             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
df_prediction_good_cols = df_prediction[x_train_med.columns.values] # keep the columns that are in training data...

# %%
bst.predict(xgb.DMatrix(df_prediction_good_cols))
# Out:
# array([ 0.36515704,  0.256385  ,  0.38384637, ...,  0.35653505,
#         0.3382495 ,  0.19095707], dtype=float32)

# %%
d = bst.get_fscore()

def get_feature_df(d):
    '''given xgboost feature score object
    put into pretty df'''
    feature = []
    f_importance = []
    for w in sorted(d, key=d.get, reverse=True):
        feature.append(w)
        f_importance.append(d[w])

    feature_import_df = pd.DataFrame(
        {'feature': feature,
         'feature importance': f_importance,
        })
    return feature_import_df

# %%
get_feature_df(d).head()
# Out:
#   feature  feature importance
# 0  m5f23l                  66
# 1  m5f23e                  59
# 2  m5f23a                  51
# 3   m5b8b                  41
# 4  hv4f1j                  38

# %%
predy = bst.predict(xgb.DMatrix(df_prediction_good_cols))

# %%
train_preds = bst.predict(xgb.DMatrix(x_train_med))

# %%
predy
# Out:
# array([ 0.48291555,  0.50567532,  0.75146991, ...,  0.31242976,
#         0.38012117,  0.16834751], dtype=float32)

# %%
train_preds
# Out:
# array([ 0.00413825,  0.00424096,  0.111378  , ...,  0.0466628 ,
#         0.17652351,  0.35860255], dtype=float32)

# %%
mean_squared_error(y_train_med, train_preds) # why is this so far above verbose training output?
# Out:
# 3.7299610920999435

# %%
xgb.plot_importance(bst,max_num_features=20)
plt.show()

# %% [markdown]
# # Parameter selection here!

# %% [markdown]
# ## Below...plug in some parameters you would like to choose between. This has only 1 for loop at the moment, indicating that you can only loop through a list of 1 parameter. Obviously, this is complicated, because certain parameters (all parameters?) interact, so it would probably be better to loop through multiple at a time. I could write code to do this, but this works fine for now to just investigate one.

# %%
# where errors go 
errs = []
models = []
# PARAMS
########
paramms = {
            "eval_metric" : 'rmse',
            'objective' : 'reg:logistic',
            'eta' : 1,
            'max_depth': 1
           }
num_rd = [1,10]
# TRAININGS
########

for i in range(len(num_rd)):    # params!
    d_train = xgb.DMatrix(x_train_med,y_train_med/11) # make training matrix
    d_valid = xgb.DMatrix(x_valid_med,y_valid_med/11) # make valid matrix
    watchlist = [(d_train, 'train'), (d_valid, 'valid')]
    print('training model {}'.format(i))
    bst = xgb.train(params=paramms,  # train on train matrix with params
                dtrain=d_train,
                evals = watchlist,
             num_boost_round=num_rd[i]) 
    models.append(bst) # add model to list of models we have tried
    # errors
    train_preds = bst.predict(xgb.DMatrix(x_train_med))
    mse = mean_squared_error(y_train_med, train_preds) 
    errs.append(mse) # add mse to list
# Out:
# training model 0
# [0]	train-rmse:0.165208	valid-rmse:0.167366
# training model 1
# [0]	train-rmse:0.165208	valid-rmse:0.167366
# [1]	train-rmse:0.146634	valid-rmse:0.148812
# [2]	train-rmse:0.142543	valid-rmse:0.1524
# [3]	train-rmse:0.140582	valid-rmse:0.153174
# [4]	train-rmse:0.139138	valid-rmse:0.151126
# [5]	train-rmse:0.136243	valid-rmse:0.152386
# [6]	train-rmse:0.135252	valid-rmse:0.150792
# [7]	train-rmse:0.133376	valid-rmse:0.1508
# [8]	train-rmse:0.131582	valid-rmse:0.151857
# [9]	train-rmse:0.130457	valid-rmse:0.152296

# %%
models
# Out:
# [<xgboost.core.Booster at 0x12472b198>, <xgboost.core.Booster at 0x12472b048>]

# %% [markdown]
# # FINALLY
#
# jeez...spent too much time trying to finesse. tried to work with classes. tried to use sklearn grid search. this was much easier. i can clean up a bit, but this isn't that hard to plug into. now i can try different parameters and pick model with lowest vlaidation error!

# %% [markdown]
# # Create Submission file

# %%
# Need to add train labels to submission too, I think
print('create submission')
preds = pd.DataFrame()
preds['challengeID'] = df_prediction['challengeID']
preds['materialHardship'] = p_test
preds.sort_values(by='challengeID').head(10)
# Out:
# create submission
#     challengeID  materialHardship
# 0             1          0.228553
# 1             2          0.208423
# 2             3          0.192934
# 3             4          0.217176
# 4             5          0.100321
# 7             8          0.186167
# 10           11          0.210725
# 11           12          0.084569
# 14           15          0.121868
# 16           17          0.103562

# %%
# tack on given train values
sub = preds.append(non_na_y_train_materialHardship)
sub.sort_values(by='challengeID').head(15)

sub.to_csv('simple_xgb.csv', index=False)

# %% [markdown]
# Here, we send in a submission that predicts all missing values (both missing MH values from train set and also values for IDs that were never in train to start).
